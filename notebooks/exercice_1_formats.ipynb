# %%
import pandas as pd
df= pd.read_csv("../Data/student_data.csv")
df.head()
df.to_json("../Data/movies.json",orient="records",indent=4)

# %%
df_movies=pd.read_json("../Data/movies.json")
df_movies.head()
pd.read_json("movies.json",lines=True)

# %%
# %pip install openpyxl

# %%
df.to_excel("../Data/gestion.xlsx",index=False)

# %%
df_excel=pd.read_excel("../Data/gestion.xlsx",sheet_name="sheet1")
df_excel.head()
